# %%
18 % 7
# Out:
# 4

# %%
l = [12,3,4,5]

# %%
l
# Out:
# [12, 3, 4, 5]

# %%
l = [1,2,3,4,5]

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
for num in l:
    if num % 2 == 0:
        print(num)
    else:
        print('Odd number!')
# Out:
# Odd number!
# 2
# Odd number!
# 4
# Odd number!

# %%
list_sum = 0

for num in l:
    list_sum = list_sum + num

print(list_sum)
# Out:
# 15

# %%
tup = (1,2,3,4,5)

for item in tup:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
l = [(2,4),(6,8),(10,12)]

# %%
l[0][1]
# Out:
# 4

# %%
for tup in l:
    print(tup)
# Out:
# (2, 4)
# (6, 8)
# (10, 12)

# %%
for (t1,t2) in l:
    print(t1)
# Out:
# 2
# 6
# 10

# %%
for (t1,t2) in l:
    print(t1 - t2)
# Out:
# -2
# -2
# -2

# %%
d = {'k1': 1,'k2': 2, 'k3': 3}

# %%
d
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3}

# %%
for item in d:
    print(item)
# Out:
# k1
# k2
# k3

# %%
for k,v in d.items():
    print(k)
    print(v)
# Out:
# k1
# 1
# k2
# 2
# k3
# 3

# %%
x = 0

while x < 10:
    print('x is currently: ',x)
    x += 1
# Out:
# x is currently:  0
# x is currently:  1
# x is currently:  2
# x is currently:  3
# x is currently:  4
# x is currently:  5
# x is currently:  6
# x is currently:  7
# x is currently:  8
# x is currently:  9

# %%
x = 0

while x < 10:
    print('x is currently: ',x)
    x +=1
    
else:
    print:('All Done!')
